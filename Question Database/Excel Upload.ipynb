# %%
physicsData = {
    1 : {
        "title":"Physical World, Units and Measurements",
        "Topics":["Units of Physical Quantities","Dimensions of Physical Quantities", "Errors in Measurements"]
    }, 
    2 : {
        "title":"Motion in a Straight Line",
        "Topics":["Distance, Displacement & Uniform motion","Non-uniform motion", "Relative Velocity", "Motion Under Gravity"]
    }, 
    3 : {
        "title":"Motion in a Plane",
        "Topics":["Vectors","Motion in a Plane with Constant acceleration", "Projectile Motion", "Relative Velocity in Two Dimensions & Uniform Circular Motion"]
    }, 
    4 : {
        "title":"Laws of Motion",
        "Topics":["Ist, IInd & IlIrd Laws of Motion","Motion of Connected Bodies, Pulley & Equilibrium of Forces", "Friction", "Circular Motion, Banking of Road"]
    }, 
    5 : {
        "title":"Work, Energy and Power",
        "Topics":["Work","Energy", "Power", "Collisions"]
    }, 
    6 : {
        "title":"System of Particles and Rotational Motion",
        "Topics":["Centre of Mass, Centre of Gravity & Principle of Moments","Angular Displacement, Velocity and Acceleration", "Torque, Couple and Angular Momentum", "Moment of Inertia, Rotational K.E. and Power", "Rolling Motion"]
    }, 
    7 : {
        "title":"Gravitation",
        "Topics":["Kepler's Laws of Planetary Motion","Newton's Universal Law of Gravitation", "Acceleration due to Gravity", "Gravitational Field, Potential and Energy", "Motion of Satellites, Escape Speed and Orbital Velocity"]
    }, 
    8 : {
        "title":"Mechanical Properties of Solids",
        "Topics":["Hooke's Law & Young's Modulus of Elasticity","Bulk and Rigidity Modulus & Work Done in Stretching a Wire"]
    }, 
    9 : {
        "title":"Mechanical Properties of Fluids",
        "Topics":["Pressure, Density Pascal's Law & Archimedes' Principle", "Fluid Flow, Reyonld's Number & Bernoulli's Principle","Viscosity & Terminal Velocity", "Surface Tension, Surface Energy & Capillarity"]
    }, 
    10 : {
        "title":"Thermal Properties of Matter",
        "Topics":["Thermometry & Thermal Expansion","Calorimetry & Heat Transfer", "Newton's Law of Cooling"]
    }, 
    11 : {
        "title":"Thermodynamics",
        "Topics":["First Law of Thermodynamics","Specific Heat Capacity & Thermodynamic Processes", "Carnot Engine, Refrigerator & Second Law of Thermodynamics"]
    }, 
    12 : {
        "title":"Kinetic Theory",
        "Topics":["Kinetic Theory of an Ideal Gas & Gas Laws","Speeds of Gas, Pressure & Kinetic Energy", "Degree of Freedom, Specific Heat Capacity & Mean Free Path"]
    }, 
    13 : {
        "title":"Oscillations",
        "Topics":["Displacement, Phase, Velocity & Acceleration of SHM","Energy in Simple Harmonic Motion", "Time Period, Frequency, Simple Pendulum & Spring Pendulum","Damped SHM, Forced Oscillations & Resonance"]
    }, 
    14 : {
        "title":"Waves",
        "Topics":["Basic of Mechanical Waves, Progressive & Stationary Waves","Vibration of String & Organ Pipe", "Beats, Interference & Superposition of Waves","Musical Sound & Doppler's Effect"]
    }, 
    15 : {
        "title":"Electric Charges and Fields",
        "Topics":["Charges & Coulomb's Law","Electric Field, Electric Field Lines & Dipole", "Electric Flux & Gauss's Law"]
    }, 
    16 : {
        "title":"Electrostatic Potential and Capacitance",
        "Topics":["Electrostatic Potential & Equipotential Surfaces","Electric Potential Energy & Work Done in Carrying a Charge", "Capacitors, Capacitance, Grouping of Capacitors & Energy Stored in a Capacitor."]
    }, 
    17 : {
        "title":"Current Electricity",
        "Topics":["Electric Current, Drift of Electrons, Ohm's Law, Resistance & Resistivity","Combination of Resistances", "Kirchhoff's Laws, Cells, Thermo emf & Electrolysis", "Heating Effects of Current", "Wheatstone Bridge & Different Measuring Instruments"]
    }, 
    18 : {
        "title":"Moving Charges and Magnetism",
        "Topics":["Motion of Charged Particle in Magnetic Field & Moment","Magnetic Field, Biot-Savart's Law & Ampere's Circuital Law", "Force & Torque on a Current Carrying Conductor", "Galvanometer and Its Conversion into Ammeter & Voltmeter"]
    }, 
    19 : {
        "title":"Magnetism and Matter",
        "Topics":["Magnetism, Gauss's Law, Magnetic Moment & Properties of Magnet","The Earth's Magnetism, Magnetic Materials and their Properties", "Magnetic Equipment’s"]
    }, 
    20 : {
        "title":"Electromagnetic Induction",
        "Topics":["Magnetic Flux, Faraday's & Lenz's Law","Motional and Static EMI & Applications of EMI"]
    }, 
    21 : {
        "title":"Alternating Current",
        "Topics":["Alternating Current, Voltage & Power","A.C. Circuit, LCR Circuit, Quality & Power Factor", "Transformers & LC Oscillations"]
    }, 
    22 : {
        "title":"Electromagnetic Waves",
        "Topics":["Electromagnetic Waves, Conduction & Displacement Current","Electromagnetic Spectrum"]
    }, 
    23 : {
        "title":"Ray Optics and Optical",
        "Topics":["Plane Mirror, Spherical Mirror & Reflection of Light","Refraction of Light at Plane Surface & Total Internal Reflection", "Refraction at Curved Surface, Lenses & Power of Lens", "Prism & Dispersion of Light", "Optical Instruments"]
    }, 
    24 : {
        "title":"Wave Optics",
        "Topics":["Wavefront, Interference of Light, Coherent & Incoherent Sources","Young's Double Slit Experiment", "Diffraction, Polarization of Light & Resolving Power"]
    }, 
    25 : {
        "title":"Dual Nature of Radiation and Matter",
        "Topics":["Matter Waves, Cathode & Positive Rays","Electron Emission, Photon Photoelectric Effect & X-ray"]
    }, 
    26 : {
        "title":"Atoms",
        "Topics":["Atomic Structure, Rutherford's Nuclear Model of Atom","Bohr Model & The Spectra of the Hydrogen Atom"]
    }, 
    27 : {
        "title":"Nuclei",
        "Topics":["Composition and Size of the Nucleus","Mass-Energy & Nuclear Reactions", "Radioactivity"]
    },
    28 : {
        "title":"Semiconductor Electronics : Materials, Devices and Simple Circuits",
        "Topics":["Solids, Semiconductors and P-N Junction Diode","Junction Transistor", "Digital Electronics and Logic Gates"]
    },
}

# %%
chemistryData = {
    1 : {
        "title":"Some Basic Concepts of Chemistry",
        "Topics":["Significant Figures, Laws of Chemical Combinations and Mole Concept", "Percent Composition and Empirical Formula", "Stoichiometric Calculations"]
    }, 
    2 : {
        "title":"Structure of Atom",
        "Topics":["Atomic Models and Dual Nature of Electromagnetic Radiation", "Bohr's model for Hydrogen Atom (Emission and Absorption Spectra)", "Dual Behaviour of Matter and Heisenberg Uncertainty Principle", "Quantum Mechanical Model of Atom"]
    }, 
    3 : {
        "title":"Classification of Elements and Periodicity in Properties",
        "Topics":["Modern Periodic Table", "Periodic Trends in Properties of Elements"]
    },
    4 : {
        "title":"Chemical Bonding and Molecular Structure",
        "Topics":["Electrovalent, Covalent and Co-ordinate Bonding", "Octet rule, Resonance and Hydrogen Bonding","Dipole Moment and Bond Polarity", "VSEPR Theory and Hybridisation", "Valence Bond and Molecular Orbital Theory"]
    }, 
    5 : {
        "title":"States of Matter",
        "Topics":["Gas laws and Ideal gas Equation", "Kinetic Theory of Gases and Molecular Speeds", "van der Waal's Equation and liquefaction of Gases", "Liquid State"]
    },
    6 : {
        "title":"Thermodynamics",
        "Topics":["First Law and Basic Fundamentals of Thermodynamics", "Laws of Thermochemistry", "Entropy and Second Law of Thermodynamics","Spontaneity and Gibb's Free Energy"]
    },
    7 : {
        "title":"Equilibrium",
        "Topics":["Law of Mass Action, Equilibrium Constant (Kc and Kp) and its Application", "Relation between K, Q and G and Factors Effecting Equilibrium", "Theories of Acids and Bases, lonic Product of Water and pH Scale", "Ionisation of Weak Acids and Bases and Relation between Ka and Kb","Common lon Effect, Salt Hydrolysis, Buffer Solutions and Solubility Product"]
    },
    8 : {
        "title":"Redox Reactions",
        "Topics":["Oxidation and Reduction Reactions", "Oxidation Number", "Disproportionation and Balancing of Redox Reactions","Electrode Potential and Oxidising, Reducing Agents"]
    }, 
    9 : {
        "title":"Hydrogen",
        "Topics":["Preparation and Properties of Hydrogen", "Preparation and Properties of Water", "Preparation and Properties of Hydrogen Peroxide"]
    },
    10 : {
        "title":"The s-Block Elements",
        "Topics":["Preparation and Properties of Alkali Metals and their Compounds", "Some Important Compounds of Sodium", "Preparation and Properties of Alkaline Earth Metals and their Compounds", "Some Important Compounds of Calcium"]
    },
    11 : {
        "title":"The p-Block Elements",
        "Topics":["Boron Family", "Carbon Family"]
    },
    12 : {
        "title":"Organic Chemistry - Some Basic Principles and Techniques",
        "Topics":["Classification and Nomenclature of Organic Compounds", "Isomerism in Organic Compounds", "Concept of Reaction Mechanism in Organic Compounds"]
    },
    13 : {
        "title":"Hydrocarbons",
        "Topics":["Alkanes", "Alkenes", "Alkynes", "Aromatic Hydrocarbons"]
    },
    14 : {
        "title":"Environmental Chemistry",
        "Topics":["Air Pollution", "Water and Soil Pollution"]
    }, 
    15 : {
        "title":"The Solid State",
        "Topics":["Properties and Types of Solids", "Crystal Structure of Solids", "Cubic System and Bragg's Equation", "Imperfection in Solids"]
    },
    16 : {
        "title":"Solutions",
        "Topics":["Solubility and Concentration of Solutions", "Vapour Pressure, Laws of Solutions and Ideal, Non-ideal Solutions", "Colligative Properties and Abnormal Molecular Masses"]
    },
    17 : {
        "title":"Electrochemistry",
        "Topics":["Conductance and Conductivity", "Electrolysis and Types of Electrolysis", "Cells and Electrode Potential, Nernst Equation","Commercial Cells and Corrosion"]
    },
    18 : {
        "title":"Chemical Kinetics",
        "Topics":["Rate of Reaction, Rate Laws and Rate Constant", "Order of Reaction and Half Life Period", "Theories of Rate of Reaction"]
    },
    19 : {
        "title":"Surface Chemistry",
        "Topics":["Adsorption", "Catalysis and Theories of Catalysis", "Colloids and Emulsions"]
    },
    20 : {
        "title":"General Principles and Processes of Isolation of Elements",
        "Topics":["Occurrence of Metals", "Metallurgical Processes", "Purification and Uses of Metals"]
    },
    21 : {
        "title":"The p-Block Elements",
        "Topics":["Nitrogen Family", "Oxygen Family", "Halogen Family", "Noble Gases"]
    },
    22 : {
        "title":"The d-and f-Block Elements",
        "Topics":["Characteristics of d-Block Elements", "Compounds of Transition Metals", "Lanthanoids and Actinoids"]
    },
    23 : {
        "title":"Coordination Compounds",
        "Topics":["Coordination Number, Nomenclature and Isomerism of Coordination Compounds", "Magnetic Moment, Valence Bond Theory and Crystal Field Theory", "Organometallic Compounds"]
    },
    24 : {
        "title":"Haloalkanes and Haloarenes",
        "Topics":["Preparation and Properties of Haloalkanes", "Preparation and Properties of Haloarenes", "Some Important Polyhalogen Compounds"]
    },
    25 : {
        "title":"Alcohols, Phenols and Ethers",
        "Topics":["Preparation and Properties of Alcohols", "Preparation and Properties of Phenols", "Preparation and Properties of Ethers"]
    },
    26 : {
        "title":"Aldehydes, Ketones and Carboxylic Acids",
        "Topics":["Methods of Preparation of Carbonyl Compounds", "Properties of Carbonyl Compounds", "Preparation and Properties of Carboxylic Acids"]
    },
    27 : {
        "title":"Amines",
        "Topics":["Aliphatic and Aromatic+ Amines", "Amides, Cyanides and Isocyanides", "Nitrocompounds, Alkyl Nitrites and Diazonium Salts"]
    },
    28 : {
        "title":"Biomolecules",
        "Topics":["Carbohydrates and Lipids", "Amino Acids and Proteins", "Nucleic Acid and Enzymes", "Vitamins and Hormones"]
    },
    29 : {
        "title":"Polymers",
        "Topics":["Classification of Polymers", "Preparation and Properties of Polymers", "Uses of Polymers"]
    },
    30 : {
        "title":"Chemistry in Everyday Life",
        "Topics":["Drugs and their Classification & Cleansing Agents"]
    },
    31 : {
        "title":"Nuclear Chemistry",
        "Topics":["Nuclear Chemistry"]
    },
}

# %%
BiologyData = {
    1 : {
        "subjectName":"Botany",
        "title":"The Living World",
        "Topics":["Characteristics of Living Organisms","Classification and Taxonomic Categories","Taxonomical Aids"]
    }, 
    2 : {
        "subjectName":"Botany",
        "title":"Biological Classification",
        "Topics":["Five Kingdom Classification","Monera","Protista","Fungi","Viruses Virioids and Prions","Lichens"]
    }, 
    3 : {
        "subjectName":"Botany",
        "title":"Plant Kingdom",
        "Topics":["Algae","Bryophytes","Pteridophytes", "Gymnosperms", "Angiosperms"]
    }, 
    4 : {
        "subjectName":"Zoology",
        "title":"Animal Kingdom",
        "Topics":["Basis of Classification of Animals","Porifera, Coelenterate, Ctenophora, Platyhelminthes, Aschelminthes","Annelida, Arthropoda, Mollusca, Echinodermata, Hemichordata, Chordata","Cyclostomata, Chondrichythes, Osteichythes Topic","Amphibia, Reptiles, Aves, Mammals"]
    }, 
    5 : {
        "subjectName":"Botany",
        "title":"Morphology of Flowering Plants",
        "Topics":["Root","Stem","Leaf","Inflorescence and Flower", "Fruit and Seed","Families - Fabaceae and Solanaceae Liliaceae"]
    }, 
    6 : {
        "subjectName":"Botany",
        "title":"Anatomy of Flowering Plants",
        "Topics":["Meristmatic Tissue and Simple","Tissue System (Epidermis and Ground Vascular) and Complex Tissue","Dicot/Monocot (Root, Stem and Leaf)", "Secondary Growth"]
    }, 
    7 : {
        "subjectName":"Zoology",
        "title":"Structural Organisation in Animals",
        "Topics":["Tissue and Epithelial Tissue","Connective Tissue","Muscular Tissue", "Neural Tissue", "Cockroach, Earthworm and Frog"]
    }, 
    8 : {
        "subjectName":"Botany",
        "title":"Cell - The Unit of Life",
        "Topics":["Cell","Prokaryotic Cells - Cell Envelope and its Modifications, Ribosomes and Inclusion Bodies","Eukaryotic Cells - Cell Organelltes"]
    }, 
    9 : {
        "subjectName":"Botany",
        "title":"Biomolecules",
        "Topics":["Essential Molecules of Biological System","Proteins and Amino Acids","Fats and Lipids","Nucleic acids and Nucleotides", "Enzymes and Cofactors", "Saccharides"]
    }, 
    10 : {
        "subjectName":"Botany",
        "title":"Cell Cycle and Cell Division",
        "Topics":["Phases of cell cycle - Interphase","M - phase and cytokinesis","Meiosis - I and II"]
    }, 
    11 : {
        "subjectName":"Botany",
        "title":"Transport in Plants",
        "Topics":["Diffusion and Active Transport","Water Potential and Osmosis","Transport of Water in Plants","Transpiration","Phloem Transport"]
    }, 
    12 : {
        "subjectName":"Botany",
        "title":"Mineral Nutrition",
        "Topics":["Mineral Elements","Plant diseases and mineral absorption","Metabolism of Nitrogen"]
    }, 
    13 : {
        "subjectName":"Botany",
        "title":"Photosynthesis",
        "Topics":["Photosynthetic Apparatus","Light Reaction","Calvin (C3) cycle, C4 Pathway and Photorespiration"]
    }, 
    14 : {
        "subjectName":"Botany",
        "title":"Respiration in Plants",
        "Topics":["Respiration and Aerobic Respiration","Glycolysis and Fermentation","Krebs cycle, ETs and Chemiosmosis", "Respiratory Quotient"]
    }, 
    15 : {
        "subjectName":"Botany",
        "title":"Plant Growth and Development",
        "Topics":["Growth and Differentiation, Dedifferentiation & Redifferentiation and Development","Plant Growth Regulators","Photoperiodism/Vernalisation"]
    }, 
    16 : {
        "subjectName":"Zoology",
        "title":"Digestion and Absorption",
        "Topics":["Digestive System","Digestion and Absorption of Digested Products","Disorders of Digestive System"]
    }, 
    17 : {
        "subjectName":"Zoology",
        "title":"Breathing and Exchange of Gases",
        "Topics":["Respiratory Organs and Mechanism of Breathing","Exchange and Transport of Gases Topic","Disordes of Respiratory System"]
    }, 
    18 : {
        "subjectName":"Zoology",
        "title":"Body Fluids and Circulation",
        "Topics":["Blood and Lymph","Circulatory Pathways and Double Circulation and Regulation of Cardiac activity","Disorders of Circulatory System"]
    }, 
    19 : {
        "subjectName":"Zoology",
        "title":"Excretory Products and Their Elimination",
        "Topics":["Excretory Products of Different Animals","Human Excretory System"]
    }, 
    20 : {
        "subjectName":"Zoology",
        "title":"Locomotion and Movement",
        "Topics":["Types of Movement and Muscle","Skeletal System and Joints","Disorders of Muscular and Skeletal System"]
    }, 
    21 : {
        "subjectName":"Zoology",
        "title":"Neural Control and Coordination",
        "Topics":["Neural System","Reflex Action & Reflex Arc","Sensory Reception & Processing"]
    }, 
    22 : {
        "subjectName":"Zoology",
        "title":"Chemical Coordination and Regulation",
        "Topics":["Human Endocrine System","Hormones of Heart, Kidney & Gastrointestinal Tract and Mechanism of Hormone Action"]
    }, 
    23 : {
        "subjectName":"Zoology",
        "title":"Reproduction in Organisms",
        "Topics":["Asexual Reproduction","Sexual Reproduction"]
    }, 
    24 : {
        "subjectName":"Botany",
        "title":"Sexual Reproduction in Flowering Plants",
        "Topics":["Flower and Pre-fertilisation","Double Fertilisation","Post-fertilisation", "Apomixis & Polyembryony"]
    }, 
    25 : {
        "subjectName":"Zoology",
        "title":"Human Reproduction",
        "Topics":["The Male Reproductive System","The Female Reproductive System","Gametogenesis and Menstrual cycle Fertilisation and Implantation", "Pregnancy and Embryonic Development and Parturition and Lactation"]
    }, 
    26 : {
        "subjectName":"Zoology",
        "title":"Reproductive Health",
        "Topics":["Reproductive Health and Population Explosion & Birth Control","Medical Termination of Pregnancy and Sexually Transmitted Diseases and Infertility",""]
    }, 
    27 : {
        "subjectName":"Botany",
        "title":"Principles of Inheritance and Variation",
        "Topics":["Mendel's law of Inheritance Inheritance of one gene and Inheritance of two genes and Linkage and Recombination","Sex Determination","Mutation and Genetic Disorders"]
    }, 
    28 : {
        "subjectName":"Botany",
        "title":"Molecular Basis of Inheritance",
        "Topics":["The DNA and RNA World","Replication and Transcription and Genetic Code and Translation","Regulation of Gene Expression","Human Genome Project/DNA Fingerprinting"]
    }, 
    29 : {
        "subjectName":"Zoology",
        "title":"Evolution",
        "Topics":["Origin of Life and Evidences for and Evolution and Adaptive Radiation and Mechanism of Evolution","Hardy-Weinberg Principle and Origin and Evolution of Man"]
    }, 
    30 : {
        "subjectName":"Zoology",
        "title":"Human Health and Diseases",
        "Topics":["Common Diseases in Humans","Immunity","AIDS and Cancer","Drugs & Alcohol Abuse"]
    }, 
    31 : {
        "subjectName":"Botany",
        "title":"Strategies for Enhancement in Food Production",
        "Topics":["Animal Husbandry","Plant Breeding","Single cell Proteins and Tissure Culture"]
    },  
    32 : {
        "subjectName":"Zoology",
        "title":"Microbes in Human Welfare",
        "Topics":["Microbes in Household and Industrial Products and Sewage Treatment","Microbes in production of Biogas and as Bio-control Agents and as Biofertilisers"]
    },  
    33 : {
        "subjectName":"Botany",
        "title":"Biotechnology - Principles and Processes",
        "Topics":["Principles of Biotechnology and Tools of Recombinant DNA Technology","Process of Recombinant DNA Technology"]
    },  
    34 : {
        "subjectName":"Botany",
        "title":"Biotechnology and Its Applications",
        "Topics":["Biotechnological Applications in Agriculture","Biotechnological Applications in Medicine"]
    },  
    35 : {
        "subjectName":"Botany",
        "title":"Organisms and Populations",
        "Topics":["Organism & Its Environment","Population Attributes and Population Growth and Population Interactions"]
    },  
    36 : {
        "subjectName":"Botany",
        "title":"Ecosystem",
        "Topics":["Ecosystem-Structure & Function and Productivity Decomposition","Energy Flow and Ecological Pyramids and Ecological Sucession","Nutrient Cycling and Ecosystem Services"]
    },  
    37 : {
        "subjectName":"Botany",
        "title":"Biodiversity and its Conservation",
        "Topics":["Biodiversity and Patterns of Biodiversity and Loss of Biodiversity","Biodiversity Conservation"]
    },  
    38 : {
        "subjectName":"Botany",
        "title":"Environmental Issues",
        "Topics":["Air Pollution & its Control","Water Pollution & its Control","Solid Wastes and Agro-Chemicals and Radioactive Wastes","Greenhouse Effect & Global Warming and Ozone Depletion and Deforestation"]
    }, 
}

# %%
import psycopg2

# %%
def create_connection():
    try:
        conn = psycopg2.connect(
            host="20.244.33.58",
            database="neuflolearndb",
            user="neufloneet",
            password="LearnNEET321",
            port="5432"  # or your custom port
        )
        return conn
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)

# %%
def execute_sql(connection, sql):
    cursor = connection.cursor()
    try:
        cursor.execute(sql)
        connection.commit()
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
    finally:
        if cursor is not None:
            cursor.close()

# %%
# Connect to the database
conn = create_connection()

# %%
# SQL for creating tables
create_subjects_table_sql = """
CREATE TABLE IF NOT EXISTS Subjects (
    SubjectID SERIAL PRIMARY KEY,
    SubjectName TEXT NOT NULL
);
"""

# %%
create_chapters_table_sql = """
CREATE TABLE IF NOT EXISTS Chapters (
    ChapterID SERIAL PRIMARY KEY,
    SubjectID INT NOT NULL,
    ChapterTitle TEXT NOT NULL,
    ChapterNumber INT NOT NULL,
    FOREIGN KEY (SubjectID) REFERENCES Subjects(SubjectID)
);
"""

# %%
create_subtopics_table_sql = """
CREATE TABLE IF NOT EXISTS Subtopics (
    SubtopicID SERIAL PRIMARY KEY,
    ChapterID INT NOT NULL,
    SubtopicName TEXT NOT NULL,  -- Ensure this column name is correct
    FOREIGN KEY (ChapterID) REFERENCES Chapters(ChapterID)
);
"""

# %%
# Execute SQL commands
execute_sql(conn, create_subjects_table_sql)
execute_sql(conn, create_chapters_table_sql)
execute_sql(conn, create_subtopics_table_sql)

# %%
def insert_subject_data(conn, subject_name):
    sql = "INSERT INTO Subjects (SubjectName) VALUES (%s) RETURNING SubjectID;"
    cur = conn.cursor()
    cur.execute(sql, (subject_name,))
    subject_id = cur.fetchone()[0]
    conn.commit()
    cur.close()
    return subject_id

# %%
def insert_chapter_data(conn, subject_id, chapter_number, chapter_title):
    sql = "INSERT INTO Chapters (SubjectID, ChapterNumber, ChapterTitle) VALUES (%s, %s, %s) RETURNING ChapterID;"
    cur = conn.cursor()
    cur.execute(sql, (subject_id, chapter_number, chapter_title))
    chapter_id = cur.fetchone()[0]
    conn.commit()
    cur.close()
    return chapter_id

# %%
def insert_subtopic_data(conn, chapter_id, subtopic_name):
    sql = "INSERT INTO Subtopics (ChapterID, SubtopicName) VALUES (%s, %s);"  # Ensure these column names are correct
    cur = conn.cursor()
    cur.execute(sql, (chapter_id, subtopic_name))
    conn.commit()
    cur.close()

# %%
def process_subject_data(conn, subject_name, subject_data):
    subject_id = insert_subject_data(conn, subject_name)
    for chapter_number, chapter_info in subject_data.items():
        chapter_title = chapter_info["title"]
        chapter_id = insert_chapter_data(conn, subject_id, chapter_number, chapter_title)
        for subtopic in chapter_info["Topics"]:
            if subtopic:  # Checks if the subtopic is not empty
                insert_subtopic_data(conn, chapter_id, subtopic)

# %%
# Assuming you have the data in dictionaries named physicsData, chemistryData, biologyData
process_subject_data(conn, "Physics", physicsData)
process_subject_data(conn, "Chemistry", chemistryData)

# %%
def process_subject_data_biology(conn, subject_data):
    insert_subject_data(conn, "Botany")
    insert_subject_data(conn, "Zoology")
    for chapter_number, chapter_info in subject_data.items():
        if chapter_info["subjectName"] == "Botany":
            subject_id = 3
        elif chapter_info["subjectName"] == "Zoology":
            subject_id = 4

        chapter_title = chapter_info["title"]
        chapter_id = insert_chapter_data(conn, subject_id, chapter_number, chapter_title)
        for subtopic in chapter_info["Topics"]:
            if subtopic:  # Checks if the subtopic is not empty
                insert_subtopic_data(conn, chapter_id, subtopic)

# %%
process_subject_data_biology(conn, BiologyData)

# %%
create_Questions_sql = """
CREATE TABLE IF NOT EXISTS Questions (
    QuestionID SERIAL PRIMARY KEY,
    ChapterID INT NOT NULL,
    SubtopicID INT,
    QuestionNo INT NOT NULL,
    Question TEXT NOT NULL,
    OptionA TEXT,
    OptionB TEXT,
    OptionC TEXT,
    OptionD TEXT,
    Year TEXT,
    Answer TEXT,  -- Changed from CHAR(1) to TEXT to accommodate multiple options
    Explanation TEXT,
    HasImage BOOLEAN DEFAULT FALSE,  -- New column to indicate the presence of an image
    FOREIGN KEY (ChapterID) REFERENCES Chapters(ChapterID),
    FOREIGN KEY (SubtopicID) REFERENCES Subtopics(SubtopicID)
);"""

# %%
execute_sql(conn, create_Questions_sql)

# %%
year = """ALTER TABLE Questions
ALTER COLUMN Year TYPE DATE USING to_date(Year, 'YYYY');
"""

execute_sql(conn, year)

# %%
image_table = """CREATE TABLE IF NOT EXISTS Images (
    ImageID SERIAL PRIMARY KEY,
    QuestionID INT NOT NULL,
    ImageURL TEXT NOT NULL,
    ContentType TEXT NOT NULL, -- E.g., 'Question', 'OptionA', 'OptionB', 'OptionC', 'OptionD', 'Explanation'
    FOREIGN KEY (QuestionID) REFERENCES Questions(QuestionID)
);"""

# %%
execute_sql(conn, image_table)

# %%
conn.commit()

# %%
conn.close()

# %%
import os
import pandas as pd
import psycopg2
import logging

# %%
# Configure logging
logging.basicConfig(filename='error_log.txt', level=logging.ERROR, 
                    format='%(asctime)s:%(levelname)s:%(message)s')

# %%
def create_connection():
    try:
        conn = psycopg2.connect(
            host="20.244.33.58",
            database="neuflolearndb",
            user="neufloneet",
            password="LearnNEET321",
            port="5432"
        )
        return conn
    except (Exception, psycopg2.DatabaseError) as error:
        logging.error(f"Connection error: {error}")
        return None

# %%
def execute_sql(connection, sql, data=None):
    cursor = connection.cursor()
    try:
        if data:
            cursor.execute(sql, data)
        else:
            cursor.execute(sql)
        connection.commit()
    except (Exception, psycopg2.DatabaseError) as error:
        logging.error(f"Error executing SQL: {error}")
        logging.error(f"SQL: {sql}")
        if data:
            logging.error(f"Data: {data}")
        connection.rollback()
    finally:
        if cursor is not None:
            cursor.close()

def preprocess_answer(answer):
    if isinstance(answer, str):
        answer = answer.strip().lower()
        # Splitting by comma to handle multiple answers and then sorting to maintain a standard order
        answer_parts = sorted(answer.replace(' ', '').split(','))
        # Joining back the sorted parts
        answer = ','.join(answer_parts)
    return answer

def insert_question(conn, row, current_file):
    try:
        row['Answer'] = preprocess_answer(row['Answer'])
        if len(row['Answer']) > 3:
            raise ValueError(f"Answer too long: {row['Answer']}")

        try:
            row['SubtopicID'] = int(row['SubtopicID'])
        except ValueError:
            raise ValueError(f"Invalid SubtopicID: {row['SubtopicID']}")

        # Convert the year integer to a date string in 'YYYY-01-01' format
        year_date = f"{row['Year']}-01-01"

        # Handle HasImage as a boolean
        has_image = row.get('HasImage', False)  # Assumes pandas reads it as boolean

        sql = """
        INSERT INTO Questions (ChapterID, SubtopicID, QuestionNo, Question, 
                               OptionA, OptionB, OptionC, OptionD, Year, Answer, 
                               Explanation, HasImage)
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
        """
        values = (row['ChapterID'], row['SubtopicID'], row['QuestionNo'],
                  row['Question'], row['Option A'], row['Option B'],
                  row['Option C'], row['Option D'], year_date, row['Answer'],
                  row['Explanation'], has_image)
        execute_sql(conn, sql, values)
    except Exception as e:
        logging.error(f"Error inserting question no {row['QuestionNo']} from file {current_file}: {e}")
        logging.error(f"Row data: {row}")
        return False
    return True

def process_excel_files(conn, directory):
    for filename in sorted(os.listdir(directory)):
        if filename.endswith('.xlsx'):
            current_file = filename
            print(f"Processing file: {filename}")
            df = pd.read_excel(os.path.join(directory, filename))
            successful_rows = 0
            for _, row in df.iterrows():
                if insert_question(conn, row, current_file):
                    successful_rows += 1
            print(f"File upload completed: {filename}. Rows uploaded: {successful_rows}")

# %% [markdown]
# # **Uploading Physics Data**

# %%
# Usage
conn = create_connection()
if conn is not None:
    process_excel_files(conn, r"D:\Neuflo\Neuflo Learn Latest\neuflo dataset\neuflo dataset\excel\PHYS")
    conn.commit()
    conn.close()
# Out:
# Processing file: PHYS_CHAPTER_01.xlsx
# File upload completed: PHYS_CHAPTER_01.xlsx. Rows uploaded: 50
# Processing file: PHYS_CHAPTER_02.xlsx
# File upload completed: PHYS_CHAPTER_02.xlsx. Rows uploaded: 51
# Processing file: PHYS_CHAPTER_03.xlsx
# File upload completed: PHYS_CHAPTER_03.xlsx. Rows uploaded: 63
# Processing file: PHYS_CHAPTER_04.xlsx
# File upload completed: PHYS_CHAPTER_04.xlsx. Rows uploaded: 65
# Processing file: PHYS_CHAPTER_05.xlsx
# File upload completed: PHYS_CHAPTER_05.xlsx. Rows uploaded: 72
# Processing file: PHYS_CHAPTER_06.xlsx
# File upload completed: PHYS_CHAPTER_06.xlsx. Rows uploaded: 92
# Processing file: PHYS_CHAPTER_07.xlsx
# File upload completed: PHYS_CHAPTER_07.xlsx. Rows uploaded: 62
# Processing file: PHYS_CHAPTER_08.xlsx
# File upload completed: PHYS_CHAPTER_08.xlsx. Rows uploaded: 11
# Processing file: PHYS_CHAPTER_09.xlsx
# File upload completed: PHYS_CHAPTER_09.xlsx. Rows uploaded: 19
# Processing file: PHYS_CHAPTER_10.xlsx
# ...

# %% [markdown]
# # **Uploading Chemistry Data**

# %%
conn = create_connection()
if conn is not None:
    process_excel_files(conn, r"D:\Neuflo\Neuflo Learn Latest\neuflo dataset\neuflo dataset\excel\CHEM")
    conn.commit()
    conn.close()
# Out:
# Processing file: CHEM_CHAPTER_01.xlsx
# File upload completed: CHEM_CHAPTER_01.xlsx. Rows uploaded: 54
# Processing file: CHEM_CHAPTER_02.xlsx
# File upload completed: CHEM_CHAPTER_02.xlsx. Rows uploaded: 66
# Processing file: CHEM_CHAPTER_03.xlsx
# File upload completed: CHEM_CHAPTER_03.xlsx. Rows uploaded: 46
# Processing file: CHEM_CHAPTER_04.xlsx
# File upload completed: CHEM_CHAPTER_04.xlsx. Rows uploaded: 129
# Processing file: CHEM_CHAPTER_05.xlsx
# File upload completed: CHEM_CHAPTER_05.xlsx. Rows uploaded: 53
# Processing file: CHEM_CHAPTER_06.xlsx
# File upload completed: CHEM_CHAPTER_06.xlsx. Rows uploaded: 76
# Processing file: CHEM_CHAPTER_07.xlsx
# File upload completed: CHEM_CHAPTER_07.xlsx. Rows uploaded: 104
# Processing file: CHEM_CHAPTER_08.xlsx
# File upload completed: CHEM_CHAPTER_08.xlsx. Rows uploaded: 22
# Processing file: CHEM_CHAPTER_09.xlsx
# File upload completed: CHEM_CHAPTER_09.xlsx. Rows uploaded: 18
# Processing file: CHEM_CHAPTER_10.xlsx
# ...

# %% [markdown]
# # **Uploading Biology Data**

# %%
conn = create_connection()
if conn is not None:
    process_excel_files(conn, r"D:\Neuflo\Neuflo Learn Latest\neuflo dataset\neuflo dataset\excel\BIO")
    conn.commit()
    conn.close()
# Out:
# Processing file: BIO_CHAPTER_01.xlsx
# File upload completed: BIO_CHAPTER_01.xlsx. Rows uploaded: 42
# Processing file: BIO_CHAPTER_02.xlsx
# File upload completed: BIO_CHAPTER_02.xlsx. Rows uploaded: 141
# Processing file: BIO_CHAPTER_03.xlsx
# File upload completed: BIO_CHAPTER_03.xlsx. Rows uploaded: 134
# Processing file: BIO_CHAPTER_04.xlsx
# File upload completed: BIO_CHAPTER_04.xlsx. Rows uploaded: 163
# Processing file: BIO_CHAPTER_05.xlsx
# File upload completed: BIO_CHAPTER_05.xlsx. Rows uploaded: 106
# Processing file: BIO_CHAPTER_06.xlsx
# File upload completed: BIO_CHAPTER_06.xlsx. Rows uploaded: 100
# Processing file: BIO_CHAPTER_07.xlsx
# File upload completed: BIO_CHAPTER_07.xlsx. Rows uploaded: 56
# Processing file: BIO_CHAPTER_08.xlsx
# File upload completed: BIO_CHAPTER_08.xlsx. Rows uploaded: 119
# Processing file: BIO_CHAPTER_09.xlsx
# File upload completed: BIO_CHAPTER_09.xlsx. Rows uploaded: 86
# Processing file: BIO_CHAPTER_10.xlsx
# ...

# %% [markdown]
# # **Excel File Check**

# %%
import os
import openpyxl
import pandas as pd

def check_excel_files_for_embedded_images(folder_path):
    # Iterate through all files in the folder
    for file in os.listdir(folder_path):
        if file.startswith('~$'):  # Skip temporary files
            continue
        if file.endswith('.xlsx'):
            file_path = os.path.join(folder_path, file)
            print(f"Checking file: {file}")

            # Load the workbook
            try:
                workbook = openpyxl.load_workbook(file_path, data_only=True)
            except Exception as e:
                print(f"Error loading workbook: {e}")
                continue

            # Iterate through each sheet in the workbook
            for sheet_name in workbook.sheetnames:
                sheet = workbook[sheet_name]
                print(f"  Sheet: {sheet_name}")

                # Using pandas to get the shape of the data
                try:
                    df = pd.read_excel(file_path, sheet_name)
                    print(f"    Data shape: {df.shape}")
                except Exception as e:
                    print(f"Error reading sheet with pandas: {e}")
                    continue

                # Check for embedded images
                if sheet._images:
                    print("    Embedded images found")
                else:
                    print("    No embedded images found")

# %%
# Example usage
folder_path = r"D:\Neuflo\Neuflo Learn Latest\neuflo dataset\neuflo dataset\excel\PHYS" # Replace with the path to your folder
check_excel_files_for_embedded_images(folder_path)
# Out:
# Checking file: PHYS_CHAPTER_01.xlsx
#   Sheet: Sheet1
#     Data shape: (50, 12)
#     No embedded images found
# Checking file: PHYS_CHAPTER_02.xlsx
#   Sheet: Sheet1
#     Data shape: (51, 12)
#     No embedded images found
# Checking file: PHYS_CHAPTER_03.xlsx
#   Sheet: Sheet1
#     Data shape: (63, 12)
#     No embedded images found
# Checking file: PHYS_CHAPTER_04.xlsx
#   Sheet: Sheet1
#     Data shape: (65, 12)
#     Embedded images found
# Checking file: PHYS_CHAPTER_05.xlsx
#   Sheet: Sheet1
#     Data shape: (72, 12)
#     No embedded images found
# Checking file: PHYS_CHAPTER_06.xlsx
#   Sheet: Sheet1
#     Data shape: (92, 12)
#     Embedded images found
# Checking file: PHYS_CHAPTER_07.xlsx
#   Sheet: Sheet1
#     Data shape: (62, 12)
#     No embedded images found
# Checking file: PHYS_CHAPTER_08.xlsx
#   Sheet: Sheet1
#     Data shape: (11, 12)
#     No embedded images found
# Checking file: PHYS_CHAPTER_09.xlsx
#   Sheet: Sheet1
#     Data shape: (19, 12)
# ...

# %%
import os
import pandas as pd

def validate_excel_columns(folder_path):
    # Define a function to validate the Year and Answer columns
    def is_valid_year(year):
        return str(year).isdigit() and len(str(year)) == 4

    def is_valid_answer(answer):
        return isinstance(answer, str) and len(answer) <=3

    # Iterate through all files in the folder
    for file in os.listdir(folder_path):
        if file.startswith('~$'):  # Skip temporary files
            continue
        if file.endswith('.xlsx') or file.endswith('.xls'):
            file_path = os.path.join(folder_path, file)
            print(f"Checking file: {file}")

            # Read the Excel file
            xls = pd.ExcelFile(file_path)

            # Iterate through each sheet in the Excel file
            for sheet_name in xls.sheet_names:
                df = pd.read_excel(xls, sheet_name)
                print(f"  Sheet: {sheet_name}")

                # Check if both Year and Answer columns exist
                if 'Year' in df.columns and 'Answer' in df.columns:
                    for index, row in df.iterrows():
                        if not is_valid_year(row['Year']) or not is_valid_answer(row['Answer']):
                            print(f"    Invalid data at row {index + 1}: Year = {row['Year']}, Answer = {row['Answer']}")
                else:
                    print("    'Year' and/or 'Answer' column not found")

# %%
# Example usage
folder_path = r"D:\Neuflo\Neuflo Learn Latest\neuflo dataset\neuflo dataset\excel\PHYS"  # Replace with the path to your folder
validate_excel_columns(folder_path)
# Out:
# Checking file: PHYS_CHAPTER_01.xlsx
#   Sheet: Sheet1
# Checking file: PHYS_CHAPTER_02.xlsx
#   Sheet: Sheet1
# Checking file: PHYS_CHAPTER_03.xlsx
#   Sheet: Sheet1
#     Invalid data at row 1: Year = 2018.0, Answer = c
#     Invalid data at row 2: Year = 2016.0, Answer = b
#     Invalid data at row 3: Year = 2015.0, Answer = b
#     Invalid data at row 4: Year = 2014.0, Answer = d
#     Invalid data at row 5: Year = 2013.0, Answer = d
#     Invalid data at row 6: Year = 2010.0, Answer = c
#     Invalid data at row 7: Year = 2007.0, Answer = d
#     Invalid data at row 8: Year = 2006.0, Answer = d
#     Invalid data at row 9: Year = 2005.0, Answer = b
#     Invalid data at row 10: Year = 2005.0, Answer = d
#     Invalid data at row 11: Year = 2004.0, Answer = b
#     Invalid data at row 12: Year = 2003.0, Answer = c
#     Invalid data at row 13: Year = 2001.0, Answer = c
#     Invalid data at row 14: Year = 2000.0, Answer = a
#     Invalid data at row 15: Year = 1999.0, Answer = b
# ...

# %% [markdown]
# # **Checking the number of questions**

# %%
import os
import pandas as pd

def count_rows_in_excel_files(directory):
    # List all files in the given directory
    files = os.listdir(directory)

    # Filter for Excel files (assuming .xlsx extension)
    excel_files = [f for f in files if f.endswith('.xlsx')]

    # Iterate through each Excel file and count the rows
    for file in excel_files:
        file_path = os.path.join(directory, file)
        try:
            # Read the Excel file
            df = pd.read_excel(file_path)

            # Get the number of rows
            num_rows = len(df)

            # Print file name and number of rows
            print(f"File: {file}, Number of Rows: {num_rows}")
        except Exception as e:
            print(f"Error reading {file}: {e}")

# %%
# Example usage
directory = r"D:\Neuflo\Neuflo Learn Latest\neuflo dataset\neuflo dataset\excel\PHYS"  # Replace with your directory path
count_rows_in_excel_files(directory)
# Out:
# File: PHYS_CHAPTER_01.xlsx, Number of Rows: 50
# File: PHYS_CHAPTER_02.xlsx, Number of Rows: 51
# File: PHYS_CHAPTER_03.xlsx, Number of Rows: 63
# File: PHYS_CHAPTER_04.xlsx, Number of Rows: 65
# File: PHYS_CHAPTER_05.xlsx, Number of Rows: 72
# File: PHYS_CHAPTER_06.xlsx, Number of Rows: 92
# File: PHYS_CHAPTER_07.xlsx, Number of Rows: 62
# File: PHYS_CHAPTER_08.xlsx, Number of Rows: 11
# File: PHYS_CHAPTER_09.xlsx, Number of Rows: 19
# File: PHYS_CHAPTER_10.xlsx, Number of Rows: 50
# File: PHYS_CHAPTER_11.xlsx, Number of Rows: 53
# File: PHYS_CHAPTER_12.xlsx, Number of Rows: 39
# File: PHYS_CHAPTER_13.xlsx, Number of Rows: 69
# File: PHYS_CHAPTER_14.xlsx, Number of Rows: 82
# File: PHYS_CHAPTER_15.xlsx, Number of Rows: 44
# File: PHYS_CHAPTER_16.xlsx, Number of Rows: 49
# File: PHYS_CHAPTER_17.xlsx, Number of Rows: 115
# File: PHYS_CHAPTER_18.xlsx, Number of Rows: 88
# File: PHYS_CHAPTER_19.xlsx, Number of Rows: 30
# File: PHYS_CHAPTER_20.xlsx, Number of Rows: 38
# ...

# %%
directory = r"D:\Neuflo\Neuflo Learn Latest\neuflo dataset\neuflo dataset\excel\CHEM"  # Replace with your directory path
count_rows_in_excel_files(directory)
# Out:
# File: CHEM_CHAPTER_01.xlsx, Number of Rows: 54
# File: CHEM_CHAPTER_02.xlsx, Number of Rows: 66
# File: CHEM_CHAPTER_03.xlsx, Number of Rows: 46
# File: CHEM_CHAPTER_04.xlsx, Number of Rows: 129
# File: CHEM_CHAPTER_05.xlsx, Number of Rows: 53
# File: CHEM_CHAPTER_06.xlsx, Number of Rows: 76
# File: CHEM_CHAPTER_07.xlsx, Number of Rows: 104
# File: CHEM_CHAPTER_08.xlsx, Number of Rows: 22
# File: CHEM_CHAPTER_09.xlsx, Number of Rows: 18
# File: CHEM_CHAPTER_10.xlsx, Number of Rows: 49
# File: CHEM_CHAPTER_11.xlsx, Number of Rows: 30
# File: CHEM_CHAPTER_12.xlsx, Number of Rows: 71
# File: CHEM_CHAPTER_13.xlsx, Number of Rows: 89
# File: CHEM_CHAPTER_14.xlsx, Number of Rows: 12
# File: CHEM_CHAPTER_15.xlsx, Number of Rows: 40
# File: CHEM_CHAPTER_16.xlsx, Number of Rows: 60
# File: CHEM_CHAPTER_17.xlsx, Number of Rows: 65
# File: CHEM_CHAPTER_18.xlsx, Number of Rows: 61
# File: CHEM_CHAPTER_19.xlsx, Number of Rows: 24
# File: CHEM_CHAPTER_20.xlsx, Number of Rows: 18
# ...

# %%
directory = r"D:\Neuflo\Neuflo Learn Latest\neuflo dataset\neuflo dataset\excel\BIO"  # Replace with your directory path
count_rows_in_excel_files(directory)
# Out:
# File: BIO_CHAPTER_01.xlsx, Number of Rows: 42
# File: BIO_CHAPTER_02.xlsx, Number of Rows: 141
# File: BIO_CHAPTER_03.xlsx, Number of Rows: 134
# File: BIO_CHAPTER_04.xlsx, Number of Rows: 163
# File: BIO_CHAPTER_05.xlsx, Number of Rows: 106
# File: BIO_CHAPTER_06.xlsx, Number of Rows: 100
# File: BIO_CHAPTER_07.xlsx, Number of Rows: 56
# File: BIO_CHAPTER_08.xlsx, Number of Rows: 119
# File: BIO_CHAPTER_09.xlsx, Number of Rows: 86
# File: BIO_CHAPTER_10.xlsx, Number of Rows: 62
# File: BIO_CHAPTER_11.xlsx, Number of Rows: 58
# File: BIO_CHAPTER_12.xlsx, Number of Rows: 54
# File: BIO_CHAPTER_13.xlsx, Number of Rows: 96
# File: BIO_CHAPTER_14.xlsx, Number of Rows: 60
# File: BIO_CHAPTER_15.xlsx, Number of Rows: 86
# File: BIO_CHAPTER_16.xlsx, Number of Rows: 95
# File: BIO_CHAPTER_17.xlsx, Number of Rows: 41
# File: BIO_CHAPTER_18.xlsx, Number of Rows: 95
# File: BIO_CHAPTER_19.xlsx, Number of Rows: 53
# File: BIO_CHAPTER_20.xlsx, Number of Rows: 51
# ...
